# %% [markdown]
# # Dependencies

# %%
import os
import cv2
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold, StratifiedShuffleSplit

# Set seeds to make the experiment more reproducible.
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
seed = 0
seed_everything(seed)

# %matplotlib inline
sns.set(style="white")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
columns = ["id_code", "level"]

data_1 = pd.read_csv("../train.csv", header=None)
data_2 = pd.read_csv("../trainLabels.csv", header=None)

data_1 = data_1.drop(0)
data_1.columns = columns
data_2.columns = columns

data_1["id_code"] = data_1["id_code"].apply(lambda x: x + ".png")
data_2["id_code"] = data_2["id_code"].apply(lambda x: x + ".jpeg")

diag_0 = data_2[data_2['level'] == 0].sample(frac=0.3, random_state=seed)
diag_oth = data_2[data_2['level'] != 0]
data_2 = diag_0.append(diag_oth)

data = pd.concat([data_1, data_2])
data = data.sample(frac = 1)
data = data.reset_index()
data = data.loc[:, ~data.columns.str.contains('index')]
data.columns = columns
data["level"] = pd.to_numeric(data["level"], downcast='integer')

display(data.head())
print(len(data))
# Out:
#             id_code  level
# 0   19462_left.jpeg      1
# 1  38e0e28d35d3.png      1
# 2  20985_right.jpeg      2
# 3   40728_left.jpeg      0
# 4  13031_right.jpeg      1
# 20721

# %% [markdown]
# # 5-Fold split

# %%
ax = sns.countplot(x="level", data=data, palette="GnBu_d")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x()+0.2, p.get_height()+6))
fig = ax.get_figure()
fig.savefig("../round_2/data.png")

# %%
test = data.tail(500)
data = data.drop(test.index)

test = test.loc[:, ~test.columns.str.contains('index')]
test = test.reset_index()
test = test.loc[:, ~test.columns.str.contains('index')]
display(len(test))
# Out:
# 500

# %%
ax = sns.countplot(x="level", data=test, palette="GnBu_d")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x()+0.2, p.get_height()+3))

# %%
data = data.reset_index()
folds = StratifiedShuffleSplit(n_splits=5, test_size=0.5, random_state=0)
# folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
for fold_n, (trn_idx, val_idx) in enumerate(folds.split(data, data['level'])):
    print('Fold: %s, Train size: %s, Validation size %s' % 
          (fold_n, len(trn_idx), len(val_idx)))
    data[('fold_%s' % fold_n)] = 0
    data[('fold_%s' % fold_n)].loc[trn_idx] = 'train'
    data[('fold_%s' % fold_n)].loc[val_idx] = 'validation'
    
display(data.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-b4eaeb5302b8> in <module>
# ----> 1 data = data.reset_index()
#       2 folds = StratifiedShuffleSplit(n_splits=5, test_size=0.5, random_state=0)
#       3 # folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
#       4 for fold_n, (trn_idx, val_idx) in enumerate(folds.split(data, data['level'])):
#       5     print('Fold: %s, Train size: %s, Validation size %s' %
#
# ~/.virtualenvs/dr/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4847                 # to ndarray and maybe infer different dtype
#    4848                 level_values = _maybe_casted_values(lev, lab)
# -> 4849                 new_obj.insert(0, name, level_values)
#    4850
#    4851         new_obj.index = new_index
#
# ~/.virtualenvs/dr/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3616         self._ensure_valid_index(value)
#    3617         value = self._sanitize_column(column, value, broadcast=False)
# -> 3618         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3619
#    3620     def assign(self, **kwargs) -> "DataFrame":
#
# ~/.virtualenvs/dr/lib/python3.6/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1145         if not allow_duplicates and item in self.items:
#    1146             # Should this be a different kind of error??
# -> 1147             raise ValueError(f"cannot insert {item}, already exists")
#    1148
#    1149         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
for fold_n, (trn_idx, val_idx) in enumerate(folds.split(data, data['level'])):
    fig, (ax1, ax2) = plt.subplots(1, 2, sharex='col', figsize=(24, 6))
    fig.suptitle('Fold%s'%fold_n, fontsize=22)    
    sns.countplot(x="level", data=data[data[('fold_%s' % fold_n)] == 'train'], palette="GnBu_d", ax=ax1).set_title('Train')
    sns.countplot(x="level", data=data[data[('fold_%s' % fold_n)] == 'validation'], palette="GnBu_d", ax=ax2).set_title('Validation')
    sns.despine()
    plt.show()

# %%
data.to_csv("../round_2/imbalance/train.csv", index=None)
test.to_csv("../round_2/imbalance/test.csv", index=None)
