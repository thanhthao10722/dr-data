# %%
import pandas as pd
import seaborn as sns

# %%
columns = ["id_code", "level"]
data_test = pd.read_csv("../imbalance_data/test.csv")

data_test.columns = columns
# Out:
#    index           id_code  level fold_0      fold_1      fold_2      fold_3  \
# 0      0   19462_left.jpeg      1  train       train  validation       train
# 2      2  20985_right.jpeg      2  train       train  validation       train
# 3      3   40728_left.jpeg      0  train       train       train  validation
# 4      4  13031_right.jpeg      1  train  validation       train       train
# 5      5  42210_right.jpeg      0  train  validation       train       train
#
#   fold_4
# 0  train
# 2  train
# 3  train
# 4  train
# 5  train
#        index           id_code  level      fold_0      fold_1      fold_2  \
# 1          1  38e0e28d35d3.png      1  validation       train       train
# 2          2  20985_right.jpeg      2       train       train  validation
# 3          3   40728_left.jpeg      0       train       train       train
# 4          4  13031_right.jpeg      1       train  validation       train
# 5          5  42210_right.jpeg      0       train  validation       train
# ...      ...               ...    ...         ...         ...         ...
# 18716  18716  2a3a1ed1c285.png      2       train  validation       train
# 18717  18717  40739_right.jpeg      0       train  validation       train
# 18718  18718    6943_left.jpeg      0       train       train       train
# 18719  18719    6947_left.jpeg      1       train       train       train
# 18720  18720    2236_left.jpeg      0       train       train       train
#
#            fold_3      fold_4
# 1           train       train
# 2           train       train
# 3      validation       train
# 4           train       train
# 5           train       train
# ...           ...         ...
# 18716       train       train
# 18717       train       train
# 18718       train  validation
# 18719  validation       train
# 18720       train  validation
#
# [18720 rows x 8 columns]

# %%
ax = sns.countplot(x="level", data=data_train, palette="GnBu_d")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x()+0.2, p.get_height()+3))

# %%
ax = sns.countplot(x="level", data=data_test, palette="GnBu_d")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x()+0.2, p.get_height()+3))
